# %%
from xray_fov.paths import outs
from xray_fov.nn.evaluate import evaluate_fov

# %%
example, mean, std, reduced_areas = evaluate_fov("373b825b51665724", 0, outs["nn-eval"]+'/fov_low_')
print(example, mean, std)
# Out:
# 42.35537 31.300486 12.119916

# %%
example, mean, std, reduced_areas = evaluate_fov("373b825b51665724", 10, outs["nn-eval"]+'/fov_low_')
print(example, mean, std)
# Out:
# 12.370867 9.8891 12.52426

# %%
example, mean, std, reduced_areas = evaluate_fov("f8a55950c9b14b8b", 0, outs["nn-eval"]+'/fov_high_')
print(example, mean, std)
# Out:
# 41.832386 37.807056 9.445478

# %%
example, mean, std, reduced_areas = evaluate_fov("f8a55950c9b14b8b", 10, outs["nn-eval"]+'/fov_high_')
print(example, mean, std)
# Out:
# 23.172777 18.401403 10.726702

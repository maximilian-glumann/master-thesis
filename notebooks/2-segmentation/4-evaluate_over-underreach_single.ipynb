# %%
from xray_fov.paths import outs
from xray_fov.nn.evaluate import evaluate_over_underreach

# %%
evaluate_over_underreach("373b825b51665724", 0, outs["nn-eval"]+'/ou_reach_low_')

# %%
evaluate_over_underreach("373b825b51665724", 10, outs["nn-eval"]+'/ou_reach_low_')

# %%
evaluate_over_underreach("f8a55950c9b14b8b", 0, outs["nn-eval"]+'/ou_reach_high_')

# %%
evaluate_over_underreach("f8a55950c9b14b8b", 10, outs["nn-eval"]+'/ou_reach_high_')
